# %% [markdown]
# # Vectors

# %%
x = [1,2,3]
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
x=[1+x^2 for x=1:10]'
# Out:
# 1x10 Array{Int64,2}:
#  2  5  10  17  26  37  50  65  82  101

# %%
indexin(x,[5,17])
# Out:
# 10-element Array{Int64,1}:
#  0
#  1
#  0
#  2
#  0
#  0
#  0
#  0
#  0
#  0

# %% [markdown]
# # Arrays / Matrices

# %%
A=[1 2;3 4];
x = [4,5];

# %%
A*x
# Out:
# 2-element Array{Int64,1}:
#  14
#  32

# %%
[i*j for i=0:1, j=2:3]
# Out:
# 2x2 Array{Int64,2}:
#  0  0
#  2  3

# %% [markdown]
# # Plotting

# %%
using Winston

x = linspace(0, 3pi, 50)
c = cos(x)
s = sin(x)

plot(x, c, "g-^", x, s, "b-o")
# Out:
# FramedPlot(...)

# %% [markdown]
# # Mathematical Formulas

# %% [markdown]
# Mathematical formulas can be written inline, as this example shows $\alpha^2 + \beta^2 = \sum_n \frac{1}{n}$.

# %% [markdown]
# And similar in a separate line as shown here
#
# \begin{equation*} \left( \sum_{k=1}^n a_k b_k \right)^2 \leq \left( \sum_{k=1}^n a_k^2 \right) \left( \sum_{k=1}^n b_k^2 \right). \end{equation*}
